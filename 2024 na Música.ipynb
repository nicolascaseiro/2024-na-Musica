# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/nicolascaseiro/2024-na-Musica/refs/heads/main/2024%20na%20M%C3%BAsica.csv", encoding='utf-8')

df.head()
# Out:
#    #                                    Música            Artista  \
# 0  1                       Sympathy is a knife         Charli xcx
# 1  2                                      Juno  Sabrina Carpenter
# 2  3                              16 CARRIAGES            Beyoncé
# 3  4                                   CHIHIRO      Billie Eilish
# 4  5  we can't be friends (wait for your love)      Ariana Grande
#
#    Popularidade  BPM            Gêneros                 Álbum Data do Álbum  \
# 0            69  132  hyperpop, art pop                  BRAT    2024-06-07
# 1            83  131                pop        Short n' Sweet    2024-08-23
# 2            63  127       pop, country         COWBOY CARTER    2024-03-29
# 3            87  110                pop  HIT ME HARD AND SOFT    2024-05-17
# 4            79  116                pop      eternal sunshine    2024-03-08
#
#   Duração  Duração_segundos  ...  Valência  Fala  Ao Vivo  Volume (dB)  \
# 0   02:31               151  ...        58     0       40           -6
# 1   03:43               223  ...        64     0       20           -4
# 2   03:47               227  ...        34     0       10           -7
# 3   05:03               303  ...        52     0        0          -13
# 4   03:48               228  ...        30     0        0           -8
#
#            Tom  Compasso  Adicionado em              Spotify ID Camelot  \
# 0      G Minor         4     2025-08-22  5c9tBmJKbTdn1vhzXHeAwW      6A
# 1      F Major         4     2025-08-22  21B4gaTWnTkuSh77iWEXdS      7B
# 2  C♯/D♭ Major         4     2025-08-22  6XXxKsu3RJeN3ZvbMYrgQW      3B
# 3      G Major         4     2025-08-22  7BRD7x5pt8Lqa1eGYC4dzj      9B
# 4      F Major         4     2025-08-22  46kspZSY3aKmwQe7O77fCC      7B
#
#            ISRC
# 0  USAT22401343
# 1  USUM72404107
# 2  USSM12401304
# 3  USUM72401988
# 4  USUM72317276
#
# [5 rows x 24 columns]

# %%
linhas, colunas = df.shape[0], df.shape[1]

print(f'Linhas: {linhas}')
print(f'Colunas: {colunas}')
# Out:
# Linhas: 200
# Colunas: 24

# %%
df.describe()
# Out:
#                 #  Popularidade         BPM  Duração_segundos  Dançabilidade  \
# count  200.000000    200.000000  200.000000        200.000000     200.000000
# mean   100.500000     58.100000  126.270000        219.090000      64.545000
# std     57.879185     16.038897   26.465244         92.354527      14.625577
# min      1.000000     16.000000   65.000000         83.000000      23.000000
# 25%     50.750000     46.750000  108.000000        173.500000      55.000000
# 50%    100.500000     58.000000  128.000000        198.000000      64.000000
# 75%    150.250000     70.000000  141.250000        237.000000      75.000000
# max    200.000000     93.000000  192.000000       1067.000000      96.000000
#
#           Energia    Acústica  Instrumentalidade    Valência        Fala  \
# count  200.000000  200.000000         200.000000  200.000000  200.000000
# mean    67.085000   23.305000           1.640000   50.330000    7.600000
# std     15.796373   24.283335           8.864723   23.110856   11.615273
# min     13.000000    0.000000           0.000000    4.000000    0.000000
# 25%     56.750000    2.000000           0.000000   31.750000    0.000000
# 50%     69.000000   13.500000           0.000000   53.000000    0.000000
# 75%     79.000000   39.000000           0.000000   68.250000   10.000000
# max     99.000000   98.000000          88.000000   96.000000   50.000000
#
#          Ao Vivo  Volume (dB)    Compasso
# count  200.00000   200.000000  200.000000
# mean    17.65000    -6.095000    3.950000
# std     18.07237     2.386304    0.279087
# min      0.00000   -19.000000    3.000000
# 25%     10.00000    -7.000000    4.000000
# 50%     10.00000    -6.000000    4.000000
# 75%     22.50000    -5.000000    4.000000
# max     90.00000    -1.000000    5.000000

# %%
df.corr(numeric_only=True)
# Out:
#                           #  Popularidade       BPM  Duração_segundos  \
# #                  1.000000     -0.149176 -0.000968         -0.067990
# Popularidade      -0.149176      1.000000  0.075347         -0.132115
# BPM               -0.000968      0.075347  1.000000         -0.174435
# Duração_segundos  -0.067990     -0.132115 -0.174435          1.000000
# Dançabilidade      0.152992      0.158610 -0.069955         -0.266126
# Energia           -0.003493     -0.106960  0.167086         -0.102542
# Acústica           0.262631     -0.033366 -0.066913          0.000987
# Instrumentalidade -0.165675      0.003435 -0.019311          0.130373
# Valência           0.164788      0.106223  0.095963         -0.210823
# Fala               0.161080     -0.022173 -0.081415          0.193061
# Ao Vivo            0.114073     -0.095575  0.142435         -0.053434
# Volume (dB)        0.002238     -0.002639  0.019425         -0.194777
# Compasso           0.008711     -0.095423 -0.121306          0.116373
#
#                    Dançabilidade   Energia  Acústica  Instrumentalidade  \
# #                       0.152992 -0.003493  0.262631          -0.165675
# Popularidade            0.158610 -0.106960 -0.033366           0.003435
# BPM                    -0.069955  0.167086 -0.066913          -0.019311
# Duração_segundos       -0.266126 -0.102542  0.000987           0.130373
# Dançabilidade           1.000000 -0.118744  0.033416          -0.037005
# Energia                -0.118744  1.000000 -0.389920          -0.059351
# Acústica                0.033416 -0.389920  1.000000          -0.122650
# Instrumentalidade      -0.037005 -0.059351 -0.122650           1.000000
# Valência                0.415900  0.263617  0.190256          -0.105060
# Fala                    0.138780 -0.108982  0.132487          -0.106041
# Ao Vivo                -0.141139  0.221263  0.161948          -0.083096
# Volume (dB)             0.058076  0.661434 -0.327988          -0.191428
# Compasso                0.108891 -0.000171  0.003744           0.006906
#
#                    Valência      Fala   Ao Vivo  Volume (dB)  Compasso
# #                  0.164788  0.161080  0.114073     0.002238  0.008711
# Popularidade       0.106223 -0.022173 -0.095575    -0.002639 -0.095423
# BPM                0.095963 -0.081415  0.142435     0.019425 -0.121306
# Duração_segundos  -0.210823  0.193061 -0.053434    -0.194777  0.116373
# Dançabilidade      0.415900  0.138780 -0.141139     0.058076  0.108891
# Energia            0.263617 -0.108982  0.221263     0.661434 -0.000171
# Acústica           0.190256  0.132487  0.161948    -0.327988  0.003744
# Instrumentalidade -0.105060 -0.106041 -0.083096    -0.191428  0.006906
# Valência           1.000000  0.091136  0.085605     0.165860  0.026723
# Fala               0.091136  1.000000 -0.000670    -0.037275  0.195321
# Ao Vivo            0.085605 -0.000670  1.000000     0.074032 -0.073228
# Volume (dB)        0.165860 -0.037275  0.074032     1.000000  0.030559
# Compasso           0.026723  0.195321 -0.073228     0.030559  1.000000

# %%
colunas_numericas = df.select_dtypes(include=['number']).columns

outliers_bool = pd.DataFrame(False, index=df.index, columns=colunas_numericas)

for col in colunas_numericas:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    outliers_bool[col] = (df[col] < limite_inferior) | (df[col] > limite_superior)

linhas_com_outliers = outliers_bool.any(axis=1)

df_outliers = df[linhas_com_outliers]

print(f"Total de linhas com pelo menos um outlier: {df_outliers.shape[0]}")
# Out:
# Total de linhas com pelo menos um outlier: 72

# %%
Q1 = duracao_numerica.quantile(0.25)
Q3 = duracao_numerica.quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['Duração_segundos'] < limite_inferior) | (df['Duração_segundos'] > limite_superior)]

print(f"Número de outliers na duração: {outliers.shape[0]}\n")

print(outliers[['Música', 'Artista', 'Duração']])
# Out:
# Número de outliers na duração: 12
#
#                               Música  \
# 40                     Still Praying
# 58                              Hope
# 63                             Alone
# 64   Crossroads feat. Gary Clark Jr.
# 65               Eternity Has Failed
# 73                              Edin
# 89            Diz Aí Qual é o Plano?
# 101                         euphoria
# 102                   Family Matters
# 170                Pálido Ponto Azul
# 172                 Poetas no Topo 4
# 179                      Melhor Vibe
#
#                                                Artista Duração
# 40   Westside Gunn,DJ Drama,Stove God Cooks,Benny T...   06:57
# 58                                     Vampire Weekend   07:57
# 63                                            The Cure   06:48
# 64                                Slash,Gary Clark Jr.   05:34
# 65                                     Bruce Dickinson   06:58
# 73                               The Smashing Pumpkins   06:46
# 89   Mc IG,MC Ryan SP,Oruam,MC PH,Mc Poze do Rodo,M...   11:43
# 101                                     Kendrick Lamar   06:23
# 102                                              Drake   07:36
# 170                                               Kant   06:13
# 172  Pineapple StormTv,Jotapê,Cesar Mc,Sain,Dk 47,L...   17:47
# 179  MC Ryan SP,Filipe Ret,Caio Luccas,Chefin,Dalla...   05:41

# %%
def tempo_para_segundos(tempo_str):
    try:
        minutos, segundos = tempo_str.split(':')
        return int(minutos) * 60 + int(segundos)
    except:
        return None

df['Duração_segundos'] = df['Duração'].apply(tempo_para_segundos)

df['Duração_segundos'] = pd.to_numeric(df['Duração_segundos'], errors='coerce')

duracao_numerica = df['Duração_segundos'].dropna()

colunas = list(df.columns)

colunas.remove('Duração_segundos')

idx = colunas.index('Duração')

colunas.insert(idx + 1, 'Duração_segundos')

df = df[colunas]

media_duracao = df['Duração_segundos'].mean()
minutos = int(media_duracao // 60)
segundos = int(media_duracao % 60)
print(f"Média da duração das músicas: {minutos} min {segundos} seg")
# Out:
# Média da duração das músicas: 3 min 39 seg

# %%
df['BPM'] = pd.to_numeric(df['BPM'], errors='coerce')

bpm_validos = df['BPM'].dropna()

Q1 = bpm_validos.quantile(0.25)
Q3 = bpm_validos.quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers_bpm = df[(df['BPM'] < limite_inferior) | (df['BPM'] > limite_superior)]

print(f"Número de outliers de BPM: {outliers_bpm.shape[0]}")
display(outliers_bpm[['Música', 'Artista', 'BPM']])
# Out:
# Número de outliers de BPM: 1
#                           Música                   Artista  BPM
# 5  Fortnight (feat. Post Malone)  Taylor Swift,Post Malone  192

# %%
media_bpm = df['BPM'].mean()
print(f"Média do BPM: {media_bpm:.2f}")
# Out:
# Média do BPM: 126.27

# %%
df_generos = df.dropna(subset=['Gêneros'])
df_generos['Gêneros_lista'] = df_generos['Gêneros'].apply(lambda x: [g.strip() for g in x.split(',')])
df_exploded = df_generos.explode('Gêneros_lista')

df_exploded.groupby('Gêneros_lista')['Popularidade'].mean().sort_values(ascending=False).head(10)
# Out:
# Gêneros_lista
# urbano latino        86.0
# k-pop                81.0
# bedroom pop          80.0
# rap metal            79.0
# metal alternativo    79.0
# banda music          77.0
# corrido              77.0
# corridos bélicos     77.0
# sierreño triste      77.0
# corridos tumbados    77.0
# Name: Popularidade, dtype: float64

# %%
df.sort_values(by='Popularidade', ascending=False)[['Música', 'Artista', 'Popularidade']].head(10)
# Out:
#                            Música                        Artista  Popularidade
# 104              Die With A Smile           Lady Gaga,Bruno Mars            93
# 123              Good Luck, Babe!                  Chappell Roan            90
# 107              Beautiful Things                   Benson Boone            89
# 103                   Not Like Us                 Kendrick Lamar            88
# 3                         CHIHIRO                  Billie Eilish            87
# 122                           Who                          Jimin            87
# 124                   Sailor Song                     Gigi Perez            87
# 33    Like Him (feat. Lola Young)  Tyler, The Creator,Lola Young            86
# 114  Si Antes Te Hubiera Conocido                        KAROL G            86
# 109         I Love You, I'm Sorry                  Gracie Abrams            86

# %%
df.sort_values(by='Dançabilidade', ascending=False)[['Música', 'Artista', 'Dançabilidade']].head(10)
# Out:
#                            Música                        Artista  \
# 175                        Barbie             MC Tuto,DJ Glenner
# 94                   Vamo Marolar  L7NNON,MC Cabelinho,Palma,HHR
# 169    Problemas de um Milionário                       WIU,Teto
# 46                     one of wun                          Gunna
# 114  Si Antes Te Hubiera Conocido                        KAROL G
# 103                   Not Like Us                 Kendrick Lamar
# 140                          TGIF                       GloRilla
# 43                           Fuel                     Eminem,JID
# 75                    Savage Funk                         Anitta
# 82               ESCADA DO PRÉDIO      PEDRO SAMPAIO,Marina Sena
#
#      Dançabilidade
# 175             96
# 94              94
# 169             93
# 46              92
# 114             92
# 103             90
# 140             89
# 43              89
# 75              89
# 82              89

# %%
df.sort_values(by='Energia', ascending=False)[['Música', 'Artista', 'Energia']].head(10)
# Out:
#                                                 Música  \
# 68                                         Light It Up
# 59                             Suffocate (feat. Poppy)
# 187                                         São Amores
# 66   AmEN! (feat. Lil Uzi Vert and Daryl Palumbo of...
# 76                                     Capa De Revista
# 69                                  Raise The Red Flag
# 53                                      Scared Of Fear
# 23                                      Can't Tame Her
# 67                                     Pictures of You
# 142              Gunz N Smoke (feat. 50 Cent & Eminem)
#
#                                                Artista  Energia
# 68                                       The Offspring       99
# 59                                 Knocked Loose,Poppy       99
# 187                                      Pabllo Vittar       96
# 66   Bring Me The Horizon,Lil Uzi Vert,Daryl Palumb...       94
# 76                                              Anitta       94
# 69                                      Marilyn Manson       93
# 53                                           Pearl Jam       92
# 23                                        Zara Larsson       91
# 67                                         Deep Purple       91
# 142                  Snoop Dogg,Dr. Dre,50 Cent,Eminem       90

# %%
df.sort_values(by='Valência', ascending=False)[['Música', 'Artista', 'Valência']].head(10)
# Out:
#                              Música                      Artista  Valência
# 118                       Too Sweet                       Hozier        96
# 105                            APT.              ROSÉ,Bruno Mars        94
# 119             MILLION DOLLAR BABY                Tommy Richman        92
# 92             Diferentão - Ao Vivo                     Dilsinho        91
# 70                       West Coast                  OneRepublic        90
# 87   Erasmo Esteves (Tijuca Maluca)  Erasmo Carlos,Rubel,Emicida        90
# 197     Vai Lá - Ao Vivo em Goiânia             Maiara & Maraisa        90
# 137      BAND4BAND (feat. Lil Baby)         Central Cee,Lil Baby        89
# 127                           Human                Lenny Kravitz        89
# 19                          Houdini                     Dua Lipa        87

# %%
df.sort_values(by='Volume (dB)', ascending=False)[['Música', 'Artista', 'Volume (dB)']].head(10)
# Out:
#                       Música  \
# 68               Light It Up
# 67           Pictures of You
# 91         Rainha da Finesse
# 76           Capa De Revista
# 167       TATTOOS ON MY FACE
# 177                  Seu Job
# 38         DENIAL IS A RIVER
# 20          Can't Get Enough
# 59   Suffocate (feat. Poppy)
# 55     The Emptiness Machine
#
#                                                Artista  Volume (dB)
# 68                                       The Offspring           -1
# 67                                         Deep Purple           -2
# 91                                                 WIU           -2
# 76                                              Anitta           -2
# 167                            Derek,Jovem Dex,Nate 22           -2
# 177  Orochi,MC GP,Leviano,DU'L,Portugal No Beat,Coelho           -2
# 38                                             Doechii           -3
# 20                                      Jennifer Lopez           -3
# 59                                 Knocked Loose,Poppy           -3
# 55                                         Linkin Park           -3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

generos_temp = df['Gêneros'].dropna().apply(lambda x: [g.strip() for g in x.split(',')])
df_temp = df.loc[generos_temp.index].copy()
df_temp['genero'] = generos_temp
df_temp = df_temp.explode('genero')

contagem_generos = df_temp['genero'].value_counts()

plt.figure(figsize=(10,6))
contagem_generos.head(10).plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Gêneros Musicais (com rap incluído)')
plt.ylabel('Quantidade de Músicas')
plt.xlabel('Gêneros')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as ticker

def formatar_tempo(segundos, pos=None):
    minutos = int(segundos) // 60
    seg = int(segundos) % 60
    return f'{minutos}:{seg:02d}'

plt.figure(figsize=(10, 6))
plt.hist(df['Duração_segundos'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Distribuição da Duração das Músicas')
plt.xlabel('Duração (min:seg)')
plt.ylabel('Número de Músicas')

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatar_tempo))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.boxplot(df['Duração_segundos'].dropna(), vert=False)
plt.title('Boxplot da Duração das Músicas')
plt.xlabel('Duração (min:seg)')

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatar_tempo))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlação entre variáveis numéricas')
plt.show()

# %%
meses_pt = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',
            'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

plt.figure(figsize=(12,6))
popularidade_por_mes.plot(marker='o')
plt.title('Popularidade Média das Músicas por Mês em 2024')
plt.xlabel('Mês')
plt.ylabel('Popularidade Média')
plt.grid(True)
plt.xticks(ticks=range(1, 13), labels=meses_pt, rotation=45)
plt.tight_layout()
plt.show()

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="Dashboard 2024 na Música", layout="wide")

def carregar_dados():
    url = "https://raw.githubusercontent.com/nicolascaseiro/2024-na-Musica/refs/heads/main/2024%20na%20M%C3%BAsica.csv"
    df = pd.read_csv(url, encoding='utf-8')
    return df

df = carregar_dados()

generos_lista = df['Gêneros'].dropna().apply(lambda x: [g.strip() for g in x.split(',')])
artistas_lista = df['Artista'].dropna().apply(lambda x: [a.strip() for a in x.split(',')])

df_temp = df.copy()
df_temp = df_temp.loc[generos_lista.index]
df_temp = df_temp.assign(Gêneros_lista=generos_lista)
df_temp = df_temp.explode('Gêneros_lista')

artistas_lista_temp = artistas_lista.loc[df_temp.index]
df_temp = df_temp.assign(Artistas_lista=artistas_lista_temp)
df_temp = df_temp.explode('Artistas_lista')

meses_pt = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',
            'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

df_temp['Data do Álbum'] = pd.to_datetime(df_temp['Data do Álbum'], errors='coerce')
df_temp['Mês'] = df_temp['Data do Álbum'].dt.month.apply(lambda x: meses_pt[x-1] if pd.notna(x) else None)

st.sidebar.header("Filtros")

def ordenar_meses(meses_selecionados):
    return sorted(meses_selecionados, key=lambda m: meses_pt.index(m))

meses_disponiveis = ordenar_meses(df_temp['Mês'].dropna().unique())
generos_disponiveis = sorted(df_temp['Gêneros_lista'].dropna().unique())
artistas_disponiveis = sorted(df_temp['Artistas_lista'].dropna().unique())

mes_selecionado = st.sidebar.multiselect('Filtrar por Mês:', meses_disponiveis)
genero_selecionado = st.sidebar.multiselect('Filtrar por Gênero:', generos_disponiveis)
artista_selecionado = st.sidebar.multiselect('Filtrar por Artista:', artistas_disponiveis)

df_filtrado = df_temp.copy()

if mes_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Mês'].isin(mes_selecionado)]

if genero_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Gêneros_lista'].isin(genero_selecionado)]

if artista_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Artistas_lista'].isin(artista_selecionado)]

indices_filtrados = df_filtrado.index.unique()
df_tabela = df.loc[indices_filtrados].copy()
df_tabela['Data do Álbum'] = pd.to_datetime(df_tabela['Data do Álbum'], errors='coerce')
df_tabela['Mês'] = df_tabela['Data do Álbum'].dt.month.apply(lambda x: meses_pt[x-1] if pd.notna(x) else None)
total_musicas_filtradas = df_tabela['Música'].nunique()

st.title("Dashboard 2024 na Música")

col1, col2, col3, col4 = st.columns(4)
col1.metric("Total de músicas", total_musicas_filtradas)
col2.metric("Média Popularidade", f"{df_filtrado['Popularidade'].mean():.2f}")
col3.metric("Total de Artistas", df_filtrado['Artistas_lista'].nunique())
col4.metric("Total de Gêneros", df_filtrado['Gêneros_lista'].nunique())

st.markdown("---")

df_grafico = df_filtrado.groupby('Gêneros_lista')['Popularidade'].mean().reset_index()

fig = px.bar(df_grafico,
             x='Gêneros_lista',
             y='Popularidade',
             title='Popularidade Média por Gênero Musical (2024)',
             labels={'Gêneros_lista': 'Gênero', 'Popularidade': 'Popularidade Média'},
             color='Popularidade',
             color_continuous_scale='Viridis',
             text=df_grafico['Popularidade'].round(2)
            )

fig.update_traces(textposition='outside', marker_line_width=1.5, marker_line_color='black')
fig.update_layout(
    plot_bgcolor='white',
    title_font=dict(size=24, family='Verdana', color='darkblue'),
    xaxis_title_font=dict(size=18, family='Verdana'),
    yaxis_title_font=dict(size=18, family='Verdana'),
    xaxis_tickangle=-45,
    xaxis_tickfont=dict(size=12, family='Verdana'),
    yaxis=dict(range=[0, 100]),
    margin=dict(l=40, r=40, t=80, b=100)
)

st.plotly_chart(fig, use_container_width=True)

st.markdown("---")

colunas_exibir = ['Música', 'Artista', 'Gêneros', 'Popularidade', 'Mês']
st.dataframe(df_tabela[colunas_exibir])
# Out:
# Overwriting app.py

# %%
df.head(59)
# Out:
#      #                                         Música  \
# 0    1                            Sympathy is a knife
# 1    2                                           Juno
# 2    3                                   16 CARRIAGES
# 3    4                                        CHIHIRO
# 4    5       we can't be friends (wait for your love)
# 5    6                  Fortnight (feat. Post Malone)
# 6    7                                  Happy Mistake
# 7    8                                           Juna
# 8    9                           Floating On A Moment
# 9   10                                          Water
# 10  11                                          Image
# 11  12           Igual Que Un Ángel (with Peso Pluma)
# 12  13                      Free Fall (feat. J. Cole)
# 13  14                     HE KNOWS (feat. Lil Nas X)
# 14  15                                       Puntería
# 15  16          I Had Some Help (Feat. Morgan Wallen)
# 16  17                                      No Angels
# 17  18                                    Deeper Well
# 18  19                         ARTIFICIAL (feat. JID)
# 19  20                                        Houdini
# 20  21                               Can't Get Enough
# 21  22                                    Little Wing
# 22  23                                         Ruined
# 23  24                                 Can't Tame Her
# 24  25                                       Stardust
# 25  26                                   reincarnated
# 26  27                        Trae The Truth in Ibiza
# 27  28                                      Like That
# 28  29                                  Show of Hands
# 29  30                                      LIL DEMON
# 30  31                                           BURN
# 31  32                                          SLIDE
# 32  33       COLE PIMP (with Ty Dolla $ign & Juicy J)
# 33  34                    Like Him (feat. Lola Young)
# 34  35                     either on or off the drugs
# 35  36                                       Étouffée
# 36  37                                 THank god 4 me
# 37  38                                Cosmo Freestyle
# 38  39                              DENIAL IS A RIVER
# 39  40                       3:AM (feat. Erykah Badu)
# 40  41                                  Still Praying
# 41  42                                         redrum
# 42  43                                       Lithonia
# 43  44                                           Fuel
# 44  45                                       Dreamin'
# 45  46  WalkOnBy (feat. Earl Sweatshirt & Rae Khalil)
# 46  47                                     one of wun
# 47  48                 Banded Up - feat. Tierra Whack
# 48  49                                      Good Good
# 49  50                                       BLUE SKY
# 50  51                            Fire in These Hills
# 51  52                                  Next Semester
# 52  53                                        WE PRAY
# 53  54                                 Scared Of Fear
# 54  55                                        Dilemma
# 55  56                          The Emptiness Machine
# 56  57                                          Waves
# 57  58                                        BYE BYE
# 58  59                                           Hope
#
#                                               Artista  Popularidade  BPM  \
# 0                                          Charli xcx            69  132
# 1                                   Sabrina Carpenter            83  131
# 2                                             Beyoncé            63  127
# 3                                       Billie Eilish            87  110
# 4                                       Ariana Grande            79  116
# 5                            Taylor Swift,Post Malone            83  192
# 6                                           Lady Gaga            54   83
# 7                                              Clairo            80  142
# 8                                        Beth Gibbons            45  140
# 9                                                Tyla            45  117
# 10                                      Magdalena Bay            69  128
# 11                              Kali Uchis,Peso Pluma            77  108
# 12                                       Tems,J. Cole            65   92
# 13                           Camila Cabello,Lil Nas X            58  125
# 14                                    Shakira,Cardi B            64  120
# 15                          Post Malone,Morgan Wallen            84  128
# 16                                  Justin Timberlake            51  112
# 17                                    Kacey Musgraves            67  110
# 18                                     Katy Perry,JID            52  129
# 19                                           Dua Lipa            81  117
# 20                                     Jennifer Lopez            30  100
# 21                                                Sia            40  160
# 22                                    Adrianne Lenker            47  109
# 23                                       Zara Larsson            50  182
# 24                                               ZAYN            59  120
# 25                                     Kendrick Lamar            72   91
# 26                                            J. Cole            63  158
# 27                 Future,Metro Boomin,Kendrick Lamar            82  162
# 28                     Future,Metro Boomin,A$AP Rocky            59  137
# 29                                             Future            74  131
# 30                        ¥$,Kanye West,Ty Dolla $ign            72  105
# 31                        ¥$,Kanye West,Ty Dolla $ign            57  108
# 32                 Denzel Curry,Ty Dolla $ign,Juicy J            52  156
# 33                      Tyler, The Creator,Lola Young            86   96
# 34                                          JPEGMAFIA            64  184
# 35                                      Vince Staples            55  135
# 36                                        ScHoolboy Q            58  136
# 37                                      Freddie Gibbs            50   77
# 38                                            Doechii            81   93
# 39                                Rapsody,Erykah Badu            41   89
# 40  Westside Gunn,DJ Drama,Stove God Cooks,Benny T...            37  127
# 41                                          21 Savage            79  172
# 42                                   Childish Gambino            59  140
# 43                                         Eminem,JID            71  138
# 44                                   Common,Pete Rock            39   89
# 45  NxWorries,Anderson .Paak,Knxwledge,Earl Sweats...            47  152
# 46                                              Gunna            80  140
# 47                            Chief Keef,Tierra Whack            40  155
# 48                      USHER,Summer Walker,21 Savage            55  141
# 49                                           Kid Cudi            50   90
# 50                                    Imagine Dragons            66  125
# 51                                  Twenty One Pilots            68  175
# 52        Coldplay,Little Simz,Burna Boy,Elyanna,TINI            69  136
# 53                                          Pearl Jam            46  168
# 54                                          Green Day            61  120
# 55                                        Linkin Park            79  184
# 56                                           Bon Jovi            37  160
# 57                                         Kim Gordon            35  146
# 58                                    Vampire Weekend            43  148
#
#                                               Gêneros  \
# 0                                   hyperpop, art pop
# 1                                                 pop
# 2                                        pop, country
# 3                                                 pop
# 4                                                 pop
# 5                                                 pop
# 6                                        art pop, pop
# 7                                         bedroom pop
# 8                                                 pop
# 9                                      afrobeats, pop
# 10                                                pop
# 11  corrido, corridos tumbados, corridos bélicos, ...
# 12      afrobeats, r&b afro, alté, afrobeat, rap, pop
# 13                                                pop
# 14                                       pop latino,
# 15                                       country, pop
# 16                                                pop
# 17                                       pop, country
# 18                                              pop,
# 19                                                pop
# 20                                                pop
# 21                                                pop
# 22                                                pop
# 23                                                pop
# 24                                                pop
# 25                   hip hop, west coast hip hop, rap
# 26                                                rap
# 27                   rap, hip hop, west coast hip hop
# 28                                                rap
# 29                                                rap
# 30                                     rap, trap soul
# 31                                     rap, trap soul
# 32                              trap soul, crunk, rap
# 33                                                rap
# 34  rap experimental, hip hop alternativo, experim...
# 35                                                rap
# 36                                                rap
# 37                           hip hop alternativo, rap
# 38                                                rap
# 39                                 neo soul, r&b, rap
# 40  boom bap, hip hop alternativo, jazz rap, south...
# 41                                                rap
# 42                                                rap
# 43                                     rap, hip hop,
# 44  hip hop, jazz rap, neo soul, east coast hip ho...
# 45            rap experimental, hip hop alternativo,
# 46                                       rap melódico
# 47      drill de chicago, drill, r&b alternativo, rap
# 48                                         r&b, , rap
# 49                                                rap
# 50                                               rock
# 51                                               rock
# 52  afrobeats, afrobeat, afropop, afroswing, dance...
# 53                          grunge, rock, post-grunge
# 54                               punk, pop punk, rock
# 55       nu metal, rap metal, rock, metal alternativo
# 56                                   glam metal, rock
# 57                                   noise rock, rock
# 58                           indie, pop barroco, rock
#
#                                       Álbum Data do Álbum Duração  \
# 0                                      BRAT    2024-06-07   02:31
# 1                            Short n' Sweet    2024-08-23   03:43
# 2                             COWBOY CARTER    2024-03-29   03:47
# 3                      HIT ME HARD AND SOFT    2024-05-17   05:03
# 4                          eternal sunshine    2024-03-08   03:48
# 5             THE TORTURED POETS DEPARTMENT    2024-04-18   03:48
# 6                                 Harlequin    2024-09-27   04:05
# 7                                     Charm    2024-07-12   03:15
# 8                            Lives Outgrown    2024-05-17   05:26
# 9                                      TYLA    2023-12-01   03:20
# 10                            Imaginal Disk    2024-08-23   03:32
# 11                                ORQUÍDEAS    2024-01-12   04:20
# 12                         Born in the Wild    2024-06-06   03:12
# 13                                   C,XOXO    2024-06-28   03:01
# 14                 Las Mujeres Ya No Lloran    2024-03-22   03:01
# 15                             F-1 Trillion    2024-08-15   02:58
# 16              Everything I Thought It Was    2024-03-15   03:28
# 17                              Deeper Well    2024-03-15   03:52
# 18                                      143    2024-09-20   02:43
# 19                         Radical Optimism    2024-05-03   03:05
# 20                This Is Me...Now (Deluxe)    2024-02-16   03:06
# 21                         Reasonable Woman    2024-05-03   03:18
# 22                            Bright Future    2024-03-22   04:32
# 23                                    VENUS    2024-02-09   03:16
# 24                    ROOM UNDER THE STAIRS    2024-05-17   03:52
# 25                                      GNX    2024-11-22   04:35
# 26                       Might Delete Later    2024-04-05   04:15
# 27                       WE DON'T TRUST YOU    2024-03-22   04:27
# 28                 WE STILL DON'T TRUST YOU    2024-04-12   03:33
# 29                            MIXTAPE PLUTO    2024-09-20   02:19
# 30                               VULTURES 1    2024-02-09   01:51
# 31                               VULTURES 2    2024-08-03   03:17
# 32     King Of The Mischievous South Vol. 2    2024-07-19   03:38
# 33                              CHROMAKOPIA    2024-10-28   04:38
# 34               I LAY DOWN MY LIFE FOR YOU    2024-08-01   02:20
# 35                               Dark Times    2024-05-24   04:28
# 36                                BLUE LIPS    2024-03-01   02:57
# 37                        You Only Die 1nce    2024-10-31   03:04
# 38               Alligator Bites Never Heal    2024-08-30   02:39
# 39                         Please Don't Cry    2024-05-17   03:33
# 40                            Still Praying    2024-11-01   06:57
# 41                           american dream    2024-01-12   04:30
# 42                                 Lithonia    2024-07-02   02:59
# 43  The Death of Slim Shady (Coup De Grâce)    2024-07-12   03:33
# 44                    The Auditorium Vol. 1    2024-07-12   04:00
# 45                                Why Lawd?    2024-06-14   03:47
# 46                               One of Wun    2024-05-10   02:24
# 47                            Almighty So 2    2024-05-10   04:26
# 48                              COMING HOME    2024-02-09   04:07
# 49                                   INSANO    2024-01-12   03:41
# 50                                     LOOM    2024-06-28   03:39
# 51                                   Clancy    2024-05-24   03:54
# 52                               Moon Music    2024-10-04   03:53
# 53                              Dark Matter    2024-04-19   04:24
# 54                                  Saviors    2024-01-19   03:18
# 55                    The Emptiness Machine    2024-09-05   03:10
# 56                                  Forever    2024-06-07   03:52
# 57                           The Collective    2024-03-08   04:14
# 58                    Only God Was Above Us    2024-04-05   07:57
#
#     Duração_segundos  ...  Valência  Fala  Ao Vivo  Volume (dB)          Tom  \
# 0                151  ...        58     0       40           -6      G Minor
# 1                223  ...        64     0       20           -4      F Major
# 2                227  ...        34     0       10           -7  C♯/D♭ Major
# 3                303  ...        52     0        0          -13      G Major
# 4                228  ...        30     0        0           -8      F Major
# 5                228  ...        28     0       10          -11      B Major
# 6                245  ...        16     0       10           -8      C Major
# 7                195  ...        45     0       10           -6  D#/E♭ Major
# 8                326  ...        16     0        0          -11      A Minor
# 9                200  ...        52     0       10           -3  D#/E♭ Minor
# 10               212  ...        85     0       10           -6      F Minor
# 11               260  ...        48     0       10           -5      F Minor
# 12               192  ...        80     0       10           -7      A Minor
# 13               181  ...        45    10       10           -7  A#/B♭ Minor
# 14               181  ...        81     0       10           -4      F Minor
# 15               178  ...        75     0       20           -5      C Major
# 16               208  ...        65     0        0           -6  A#/B♭ Minor
# 17               232  ...        35     0       10           -8      C Major
# 18               163  ...        14     0       30           -7      C Minor
# 19               185  ...        87     0        0           -5      A Minor
# 20               186  ...        64     0        0           -3      C Major
# 21               198  ...        14     0       10           -4  F#/G♭ Minor
# 22               272  ...        16     0        0          -12      F Major
# 23               196  ...        55    10       10           -3  F#/G♭ Minor
# 24               232  ...        65     0       10           -6      A Major
# 25               275  ...        75    20       30           -5      G Major
# 26               255  ...        53    10       30           -8      G Major
# 27               267  ...        31    20       10           -5      B Minor
# 28               213  ...        38    30       40           -4  G#/A♭ Minor
# 29               139  ...        30     0        0           -6      B Major
# 30               111  ...        72    30       80           -6      E Minor
# 31               197  ...        44     0       10           -6  A#/B♭ Minor
# 32               218  ...        76    10       10           -6  G#/A♭ Minor
# 33               278  ...        19     0       10           -7      E Minor
# 34               140  ...        63    10       70           -6  F#/G♭ Minor
# 35               268  ...        47    40       20           -8      G Minor
# 36               177  ...        42    10       10           -8  C♯/D♭ Major
# 37               184  ...        65    20       10           -5      A Minor
# 38               159  ...        62    30        0           -3  F#/G♭ Minor
# 39               213  ...        64    30       10           -6      F Minor
# 40               417  ...         5     0       10           -7      C Major
# 41               270  ...        24     0       30           -9      D Major
# 42               179  ...        17     0       10           -8  C♯/D♭ Major
# 43               213  ...        12    10       10           -5  C♯/D♭ Major
# 44               240  ...        60    20       40           -3      D Major
# 45               227  ...        71    20       10          -11      G Minor
# 46               144  ...        29    20       10           -5  A#/B♭ Minor
# 47               266  ...        19     0       30           -5  C♯/D♭ Major
# 48               247  ...        57    10       10           -5      G Minor
# 49               221  ...        40     0        0           -7  C♯/D♭ Minor
# 50               219  ...        27     0       10           -8  C♯/D♭ Major
# 51               234  ...        13    10       10           -5      E Major
# 52               233  ...        67     0        0           -8      F Minor
# 53               264  ...        36    10       10           -4      G Minor
# 54               198  ...        67     0       20           -3      D Major
# 55               190  ...        81     0       10           -3      G Major
# 56               232  ...        34     0       10           -6      B Minor
# 57               254  ...         4     0       10           -9      G Minor
# 58               477  ...        35     0       10           -6      C Major
#
#     Compasso  Adicionado em              Spotify ID Camelot          ISRC
# 0          4     2025-08-22  5c9tBmJKbTdn1vhzXHeAwW      6A  USAT22401343
# 1          4     2025-08-22  21B4gaTWnTkuSh77iWEXdS      7B  USUM72404107
# 2          4     2025-08-22  6XXxKsu3RJeN3ZvbMYrgQW      3B  USSM12401304
# 3          4     2025-08-22  7BRD7x5pt8Lqa1eGYC4dzj      9B  USUM72401988
# 4          4     2025-08-22  46kspZSY3aKmwQe7O77fCC      7B  USUM72317276
# 5          4     2025-08-22  2OzhQlSqBEmt7hmkYxfT6m      1B  USUG12401028
# 6          4     2025-08-22  5DQIZ8XC0EP7cfRFrtzY5h      8B  USUG12405111
# 7          4     2025-08-22  2mWfVxEo4xZYDaz0v7hYrN      5B  USA2P2416229
# 8          4     2025-08-22  0WH39BFVGotzXe3torfzvK      8A  GBCEL2100652
# 9          4     2025-08-22  4WzfrBu4t3LVv1BSKWugbW      2A  USSM12305126
# 10         3     2025-08-22  0QW0KPBXXv67haGjbtkRRB      4A  USQE92400097
# 11         4     2025-08-22  6XaJfhwof7qIgbbXO5tIQI      4A  USUM72315072
# 12         4     2025-08-22  3cuUZnjDwk4cUJCFinYbAC      8A  USRC12401742
# 13         4     2025-08-22  5TdrCQVt3l1uEz3pFdTgXC      3A  USUG12402116
# 14         4     2025-08-23  2dYXrWkNO40NXy2Q3IYLRc      4A  USQX92400523
# 15         4     2025-08-22  5IZXB5IKAD2qlvTPJYDCFB      8B  USUM72404990
# 16         4     2025-08-22  3Llg6UrxeStZxQJNjEQrlM      3A  USRC12400002
# 17         4     2025-08-22  333XFHKsHU0pOocFzBgrJi      8B  USUM72316291
# 18         4     2025-08-22  3UxPCKSa8fPIhP7KMSD0HW      5A  USUM72407749
# 19         4     2025-08-22  6D8y7Bck8h11byRY88Pt2z      8A  GBAHT2301246
# 20         4     2025-08-22  6SSZfUwJuFmPvLssmMhTMj      8B  QMRSZ2301148
# 21         4     2025-08-22  4ZK786lHXz8nZ8NwODGc6L     11A  USAT22400523
# 22         4     2025-08-22  3cGZNocKeVtXgjugVYuMyi      7B  GBAFL2300323
# 23         4     2025-08-22  1G1kKHczSz6Xqv5dCmtkL4     11A  USSM12210918
# 24         4     2025-08-22  4266h07udCdZ83jswW10IG     11B  USUG12401420
# 25         4     2025-08-22  0RgjEkSbeuStKfT2Pa4Zai      9B  USUG12408500
# 26         3     2025-08-22  4E2fOeF5A6onC10OtnjXJa      9B  USUG12402412
# 27         4     2025-08-22  2tudvzsrR56uom6smgOcSf     10A  USSM12402041
# 28         4     2025-08-22  0cGn4vxyoBftN61XUv2aQk      1A  USSM12403211
# 29         4     2025-08-22  3aCPResPDNae3pXTocGpYe      1B  USSM12406727
# 30         4     2025-08-22  7BPadP3q9qwMkho3IMPU99      9A  QZ7XS2400009
# 31         4     2025-08-22  5MGMXOhVvwzCjFgdQsFokR      3A  TLVEM2467039
# 32         4     2025-08-22  4vdDAdLtmTqFR1J4AO4cBf      1A  USC4R2443043
# 33         3     2025-08-22  6jbYpRPTEFl1HFKHk1IC0m      9A  USQX92405794
# 34         3     2025-08-22  3EWaU5exMayFzQMkIfTX7w     11A  QM7282468581
# 35         5     2025-08-22  592A3x9nMXoL3Ay5rKgSwW      6A  USUM72404697
# 36         4     2025-08-22  7CwO2esrH095tjxmJVMY2E      3B  USUM72401064
# 37         4     2025-08-22  7rOMXlhgozetHpzmJciBjm      8A  QMDA62478842
# 38         4     2025-08-22  1eTaznNW4Xxtx9za2SMTXB     11A  USUG12405664
# 39         4     2025-08-22  44BRidSOFkXcKH3oZzHKdR      4A  QMJMT2405253
# 40         4     2025-08-22  4iRh9CuSqd3aF2jSA1v6Xj      8B  QZS7J2415851
# 41         4     2025-08-22  52eIcoLUM25zbQupAZYoFh     10B  USSM12309164
# 42         4     2025-08-22  4JfpJrrGNXRj2yXm1fYV23      3B  USRC12402124
# 43         4     2025-08-22  5In8B6Om5OKrhwBMB4tXSi      3B  USUG12403410
# 44         4     2025-08-22  7qiCLJzwFyyyjckrYHVkOh     10B  USC4R2443030
# 45         4     2025-08-22  36dXojpK4JbefZoCLRVVMF      6A  US2S72400018
# 46         4     2025-08-22  4Na2HfNSr58chvfX69fy36      3A  USAT22403437
# 47         4     2025-08-22  7tmgmrJYAGshsUHUNWPMlO      3B  QMRSZ2203237
# 48         4     2025-08-22  3jK1QRugwuAKAKOrtac7a2      6A  QZS7J2331813
# 49         4     2025-08-22  74uNMBwFmCG9OXHg5LX16K     12A  USUM72312226
# 50         4     2025-08-22  2Morv8EWzWFsfbqG8vdUfy      3B  USUM72404005
# 51         4     2025-08-22  1BANPzYIhCQkJ1ZFq2Fb0O     12B  USAT22402063
# 52         4     2025-08-23  7xrEnNo99wrmIs8ZK3RZMK      4A  GBAYE2400890
# 53         4     2025-08-22  5zAga8KU22nzojKc6ZBWOV      6A  USUG12309751
# 54         4     2025-08-22  4NrGMEm5SvvpJ9Tk1Rq3cP     10B  USRE12201093
# 55         4     2025-08-22  2PnlsTsOTLE5jnBnNe2K0A      9B  USWB12403464
# 56         4     2025-08-22  3fRs5XDtcKe3TzFTlsqIOv     10A  USUG12401207
# 57         4     2025-08-22  3b34EvMAFHcdRBujeo9e6t      6A  USMTD2300380
# 58         4     2025-08-22  5sBrebz7XnIbwSdWgWasLr      8B  USSM12400086
#
# [59 rows x 24 columns]
